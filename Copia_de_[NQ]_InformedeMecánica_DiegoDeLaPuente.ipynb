# %% [markdown]
# #**VECTORES CONCURRENTES Y DE FUERZA**
#
# *Diego Andrés De La Puente Arévalo. Ingeniería Biomédica
# Facultad de Ingeniería, Universidad Autónoma de Bucaramanga.*

# %% [markdown]
# ##**Resumen:**
# > En este informe de laboratorio se analiza los dos montajes de sistema de fuerzas concurrentes, en el cual se estudia la distintas representaciones de vectores que se forman. Se utilizaron los conceptos básicos de vectores para dar solución a operaciones entre vectores, utilizando el método del paralelogramo, del polígono y algebraico. Por otra parte también es necesario tener conocimiento de conceptos de fuerza, clases y diagramas de fuerza. Se aplican conocimientos analíticos y gráficos para determinar el vector resultante de un sistema de vectores.

# %% [markdown]
# ##**Introducción:**
# > A continuación en este informe se muestran resultados y análisis de las prácticas 3 (Vectores Concurrentes) y 4 (Vectores de Fuerza), con el fin de aprender a usar los diferentes métodos que se pueden aplicar para lograr hallar la fuerza que aplica un vector a un punto, teniendo en cuenta principalmente las posiciones Fx y Fy de los vectores.

# %% [markdown]
# ##**Desarrollo experimental**
# > Se realizaron 2 sesiones en la primera teníamos 5 vectores (imagen 1) de los cuales tomamos los ángulos respecto al eje x positivo y la fuerza de todos menos del vector 5 la cual mediante el uso de diferentes métodos lo hallamos.

# %% [markdown]
# ##**Desarrollo experimental**
# > Se realizaron 2 sesiones en la primera teníamos 5 vectores (imagen 1) de los cuales tomamos los ángulos respecto al eje x positivo y la fuerza de todos menos del vector 5 la cual mediante el uso de diferentes métodos lo hallamos.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# > Para todos los vectores se les realizó el cálculo de la posición respecto al eje X y Y de todos los vectores.
# >
# > En la segunda sesión 2 (imagen 2) teníamos igualmente 5 vectores con los mismos datos al igual de las mismas incógnitas es decir también hallamos las posiciones respecto a X y Y y la fuerza del vector desconocido(X), haciendo uso principalmente de Dinamómetro(Para medir las fuerzas), Soportes universales(Para fijar todo el montaje).

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# > Para los resultados tuvimos en cuenta de que todos los vectores en ambas sesiones son concurrentes debido a que la dirección de los vectores llegan a un mismo punto que en este caso para ambos es el origen.

# %% [markdown]
# ##**Resultados y discusión**
#
# > Un vector cuenta con unos parámetros establecidos los cuales son: el módulo o magnitud, el sentido, la dirección, punto origen o también llamado punto de aplicación. Como se muestra en la figura en la figura 1.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# > Existen dos métodos gráficos para encontrar el vector resultante, por medio del polígono y paralelogramo. El paralelogramo sirve para sumar dos vectores a la vez y el polígono es para dos o más vectores a la vez, pero los dos llegan al mismo resultado.
# > Por otro lado, el método analítico también es una técnica para llegar al vector resultante, el cual permite realizar la suma de vectores de varios vectores a la vez y es el más preciso. Se realiza por medio de los componentes del vector, es decir la suma de los componentes en X y Y.   (Delgado Cepeda et al.).

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# > **F(N)cos(O°)** para respecto a X y **F(N)sen(O°)** para respecto a Y.

# %% [markdown]
# >Fx1= 3,8 cos(28)  =  3,36
# >
# > Fx2= 2,1 cos(150)= -1,81
# >
# > Fx3= 1,6 cos(195)= -1.55
# >
# > Fx4= 2,1 cos(222)= -1,56
# >
# > Fy1= 3,8 sen(28)  =  1,78
# >
# > Fy2= 2,1 sen(150)=  1,05
# >
# > Fy3= 1,6 sen(195)= -0,41
# >
# > Fy4= 2,1 sen(222)= -1,41

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# > La posición del vector 5 sería el resultado del método del paralelogramo por -1.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# > Para hallar Fx y Fy del Vector desconocido(X) utilizamos los siguientes métodos:

# %% [markdown]
# >Método analitico
#
# Vector resultante = **Σ Vxi + Vyj**
#
#     = -(4,90j - 4,75j - 1,91j + 2,01j)
#     =0i
#     = -(4,11j + 3,33j - 1,49j - 2,87j)
#     =-3,08

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# > La posición del vector X sería el resultado del método del paralelogramo por -1.

# %% [markdown]
# ##**Conclusiones**
# > Para hacer este trabajo fue necesario tener conocimientos previos de ciertos conceptos claves. Por ejemplo, vector, que se constituye de tres partes (módulo, dirección y sentido). Otro concepto trabajado fue la fuerza, la cual puede combinarse con otras, formando una fuerza resultante (principio de superposición), esta fuerza resultante puede ser cero (equilibrio de un cuerpo rígido).
# Entonces podemos concluir que la fuerza si es un vector y que para hacer coincidir la teoría con la experiencia se requiere tener los datos lo más exactos posible.

# %% [markdown]
# ##**Bibliografía:**
# **1-**
# *D. Cepeda, J. Francisco, M. Garrido, and Martha, “Acerca de este ePub FÍSICA I - SANTIAGO ACOSTA, RUBÉN DARÍO.” [Online]. Available: http://prod77ms.itesm.mx/podcast/EDTM/ID267.pdf”*
#
# **2-**
# *V. DE, “GUÍA VECTORES DE FUERZA LAB MECÁNICA.docx,” Google Docs, 2020. https://docs.google.com/document/d/1BpiN63Oj1EyEkKWfcFzxR7hzz3cquD1t/edit (accessed Sep. 02, 2022).*.
